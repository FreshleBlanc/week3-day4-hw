# %% [markdown]
# # APIs

# %% [markdown]
# ## Tasks Today:
# 1) <b>Requests and the pokemon API </b> <br>

# %% [markdown]
# # working with APis

# %% [markdown]
# <p> What exactly is an API? <br> <br>
# API is the acronym for Application Programming Interface, which is a software intermediary that allows two applications to talk to each other. Each time you use an app like Facebook, send an instant message, or check the weather on your phone, you're using an API. </p>

# %% [markdown]
# ### The Poke API  allows you to retreive a pokemon's information from PokeAPI https://pokeapi.co/

# %%
# making an API call
import requests


response = requests.get('https://pokeapi.co/api/v2/pokemon/squirtle')

print(response)


if response.status_code == 200:
    print('Success')
    data = response.json()
else:
    print(f' Error, Status code{response.status_code}')
    
print(data)
# Out:
# <Response [200]>
# Success
# ...

# %% [markdown]
# ### Display a Pokemon's name, weight, abilities, and types

# %%
# get the name
print(data['name'])
# Out:
# squirtle

# %%
# get types
data['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]

# %%
# get weight
data['weight']
# Out:
# 90

# %%
# get abilities
data['abilities']
# Out:
# [{'ability': {'name': 'torrent',
#    'url': 'https://pokeapi.co/api/v2/ability/67/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'rain-dish',
#    'url': 'https://pokeapi.co/api/v2/ability/44/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
ability_names = [ability['ability']['name'] for ability in data['abilities']]

# %%
ability_names
# Out:
# ['torrent', 'rain-dish']

# %%
# Create a structure for a single pokemon


pokemon = {
    'abilities': ability_names,
    'name': data['name'],
    'types': data['types'],
    'weight': data['weight']
}

# %%
pokemon
# Out:
# {'abilities': ['torrent', 'rain-dish'],
#  'name': 'squirtle',
#  'types': [{'slot': 1,
#    'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}],
#  'weight': 90}

# %% [markdown]
# #### Create a function to Pull in your own Pokemon's data

# %%
# Create a function that does the following:
# Asks a user to input a pokemon name
# Requests the poke api for that pokemon's information
# Creates the dictionary from above with that pokemons information
    # In addition to the above keys, include the height and the "front_default" sprite
# Returns the dictionary



#we need to ask for user input((()(((((())))))))
#store the input in variable = pokemon(((((()()(()))))))
#search the api for *pokemon*(()(((()((()((()))))))))
#make dictionay with *pokemon* info

def poke_api_call(pokemon-none):
    if not pokemon:
        pokemon_search = input('What pokemon are you interested in?')
    
       pokemon_request = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon_search

    if pokemon_search in pokemon_request:
        print('pokemon')

if response.status_code == 200:
    print('Success')
    data = response.json()
else:
    print(f' Error, Status code{response.status_code}')



ability_names = [ability['ability']['name'] for ability in data['abilities']]


pokemon_dict = {
    'abilities': ability_names,
    'name': data['name'],
    'types': data['types'],
    'weight': data['weight'],
    'height': data['height'],
    'sprite': data['sprites']['front_default'] 
}
# Out:
# What pokemon are you interested in?ditto
# <Response [200]>

# %%
def poke_api_call(pokemon=None):
    if not pokemon:
        pokemon = input('What pokemon do you want to select?')
    
    response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon}')

    if response.status_code == 200:
        print('SUCCESS')
        data = response.json()
    else:
        print(f'ERROR, STATUS CODE {response.status_code}')
        return 'Error'
    
    ability_names = [item['ability']['name'] for item in data['abilities']]
    
    poke_dict = {
        'abilities': ability_names,
        'name': data['name'],
        'types': data['types'],
        'weight': data['weight'],
        'height': data['height'],
        'sprite': data['sprites']['front_default']
    }
    
    return poke_dict

# %%
print('pikachu')
# Out:
# pikachu

# %% [markdown]
# Choose your pokemon

# %%
from random import randint
# Random number generated for each pokemon id
random_team = [randint(1,898) for i in range(6)]

your_team = ['electabuzz', 'haunter','tyranitar','blaziken','marowak','dragonair']

# %% [markdown]
# #### Use your function to create a dictionary of your Johto League 6  (favorite 6 pokemon)

# %%
# Place all 6 of your pokemon on the object below, each pokemon should have at least as much info as Pikachu did.

import requests

my_six_pokemon = {}



for pokemon in your_team:
    
    poke_dict = poke_api_call(pokemon)
    
    my_six_pokemon [ 
        pokemon
    ] = poke_dict

print(my_six_pokemon)
# Out:
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# ...

# %% [markdown]
# ## Lets create a class called 'Pokemon' and create our pokemon as instances

# %%
class Pokemon():
    pass

# %%
class Pokemon():
    def __init__(self, name):
        self.abilities = []
        self.name = name
        self.types = []
        self.weight = None
        self.height = None
        self.sprite = None
        self.poke_api_call()
        
    def poke_api_call(self):
        response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{self.name}')

        if response.status_code == 200:
            data = response.json()
        else:
            return 'Error'

        ability_names = [item['ability']['name'] for item in data['abilities']]
        
        self.types = data['types']
        self.abilities = ability_names
        self.weight = data['weight']
        self.height = data['height']
        self.sprite = data['sprites']['front_default']

# %% [markdown]
# ### Let's Catch some Pokemon

# %%
pokedex = {}

# %%
import requests
class Pokedex:
    def __init__(self, player_name):
        self.player_name = player_name
        self.pokemon = {}
        
    def add_pokemon(self, name):
        self.pokemon[name] = Pokemon(name)
        print(f"{name} was added to {self.player_name}'s pokedex.")
    
    
    def lookup_pokemon(self):
        pokemon = input('What pokemon do you want to select?')
        response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon}')
        
        data = response.json()
        #print('test')
        #print(data['name'])
        #print(data['abilities'][0]['name'])
        print(f" {data['name']}, {data['types'][0]}, {data['abilities'][1]['ability']['name']}, {data['abilities'][0]['ability']['name']}, {data['sprites']['front_default']}, {data['weight']}")
        
        #print(data)
        
duck = Pokedex('devon')

duck.lookup_pokemon()
        
    # Add a pokemon lookup method to lookup a pokemon and display it's information (In a user friendly way)
# Out:
# What pokemon do you want to select?ditto
#  ditto, {'slot': 1, 'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}, imposter, limber, https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/132.png, 40

# %%
def poke_api_call(pokemon=None):
    if not pokemon:
        pokemon = input('What pokemon do you want to select?')
    
    response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon}')

    if response.status_code == 200:
        print('SUCCESS')
        data = response.json()
    else:
        print(f'ERROR, STATUS CODE {response.status_code}')
        return 'Error'
    
    ability_names = [item['ability']['name'] for item in data['abilities']]
    
    poke_dict = {
        'abilities': ability_names,
        'name': data['name'],
        'types': data['types'],
        'weight': data['weight'],
        'height': data['height'],
        'sprite': data['sprites']['front_default']
    }
    
    return poke_dict

# %% [markdown]
# ## Exercise 1:

# %% [markdown]
# ### Create a Method prints an image of your pokemon
#
# <p>HINT: You may need another attribute as well to store your image url within. </p>

# %%
# Display an image in Jupyter notebook
from IPython.display import Image

display(Image( 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/7.png', width = 300))

# %%
# recreate your pokemon class here
from IPython.display import Image
import requests

class Pokemon():
    def __init__(self, name=None):
        if name : 
            self.name = name
        else:
            self.name = input('What pokemon do you want to select?')
        self.abilities = []
        
        self.types = []
        self.weight = None
        self.height = None
        self.sprite = None
        self.poke_api_call()
        
    def poke_api_call(self):
        response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{self.name}')

        if response.status_code == 200:
            data = response.json()
        else:
            return 'Error'
        
       
        ability_names = [item['ability']['name'] for item in data['abilities']]
        
        self.types = data['types']
        self.abilities = ability_names
        self.weight = data['weight']
        self.height = data['height']
        self.sprite = data['sprites']['front_default']



    def lookup_pokemon(self):
        pokemon = input('What pokemon do you want to select?')
        response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon}')
        
        data = response.json()
       
        
    def pokemon_pic(self):
        
        print('self.sprite')
        print(self.sprite)
        display(Image(self.sprite, width = 300))
        
    def evolved(self):
        evolved_form = input('what is the evolved for of this pokemon?')
        self.name = evolved_form
        self.poke_api_call()
        self.pokemon_pic()

# %%
my_pokemon = Pokemon()
# Out:
# What pokemon do you want to select?pikachu

# %%
my_pokemon.evolved()

# %%
ditto = Pokemon('ditto')
pikachu = Pokemon('pikachu')
mewtwo = Pokemon('mewtwo')

ditto.pokemon_pic()
pikachu.pokemon_pic()
mewtwo.pokemon_pic()
# Out:
# {'abilities': [{'ability': {'name': 'limber', 'url': 'https://pokeapi.co/api/v2/ability/7/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'imposter', 'url': 'https://pokeapi.co/api/v2/ability/150/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 101, 'forms': [{'name': 'ditto', 'url': 'https://pokeapi.co/api/v2/pokemon-form/132/'}], 'game_indices': [{'game_index': 76, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 76, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 76, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 132, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 132, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 132, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 132, 'version': {'name': 'ruby',
# ...

# %%
# Calling our new method
pikachu = Pokemon('pikachu')
# Out:
# {'abilities': [{'ability': {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'lightning-rod', 'url': 'https://pokeapi.co/api/v2/ability/31/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 112, 'forms': [{'name': 'pikachu', 'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}], 'game_indices': [{'game_index': 84, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 84, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 84, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 25, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 25, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 25, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 25, 'version': {'name': 'ruby'
# ...

# %% [markdown]
# ## Exercise 2:

# %% [markdown]
# ### Create a Method that evolves your Pokemon
# If your pokemon can't evolve any further print a message that says "\<name of pokemon> can't evolve."

# %% [markdown]
# Now let's evolve a few

# %%
import requests

from IPython.display import Image


class Pokemon():
    def __init__(self, name):
        print('Initializing Pokemon')
        self.abilities = []
        self.name = name
        self.types = []
        self.weight = None
        self.height = None
        self.sprite = None
        self.poke_api_call()
        
    
    def poke_api_call(self):
        #print('Making API Call')
        #response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{self.name}')
        #data = response.json()
        
        
        #print(data)
        
        
        #self.sprite = data['sprites']['front_default']
        
        #print(response)
        
        print('API Call finished')
    
    
    def pokemon_pic(self):
        pokemon = input('What pokemon do you want to select?')
        print('self.sprite')
        print(self.sprite)
        display(Image(self.sprite, width = 300))

# %%
pikachu = Pokemon('pikachu')
pikachu.pokemon_pic()
# Out:
# Initializing Pokemon
# Making API Call
# ...

# %% [markdown]
# #  Final Exercise: <br> <br>Create a Move_Tutor Class that will allow the Pokemon Class to inherit a move list.
# <br>
# <p>for an added bonus you can make sure that if a pokemon has 4 moves the user can choose one of them to replace with a new move. </p>

# %%
class Move_Tutor:
    def __init__(self):
        self.move_list = []

# %%
pikachu.teach_move()
# Out:
# What move would you like to teach pikachu? spark
# pikachu learned spark!

# %%
pikachu.show_moves()
# Out:
# pikachu's moves'
# thunder
# surf
# earthquake
